# %%
cd Desktop/PRABHU\ SIR
# Out:
# /home/mrinalgouda/Desktop/PRABHU SIR

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import SPHA

# %% [raw]
# FINE WORKING

# %% [markdown]
# The above figure shows the plots for different SPH approximations.

# %%
import SPHA

# %%
run SPHA.py

# %%
import SPHA

# %%
run SPHA.py
