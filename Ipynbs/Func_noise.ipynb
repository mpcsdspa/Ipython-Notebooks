# %%
cd Desktop/PRABHU\ SIR
# Out:
# /home/mrinalgouda/Desktop/PRABHU SIR

# %%
import gauss, spline, gauss_derivative, spline_derivative

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n = 101
x = np.mgrid[-1:1:n*1j]
m = 0.02

# %% [markdown]
# #### Density constant

# %%
x1 = spline.modify_x(x,0.2)
spline.error(x1)
spline.l2error(x1)
# Out:
# 300
# 300
# 300

# %%
x1 = spline.modify_x(x,0.5)
spline.error(x1)
spline.l2error(x1)
# Out:
# 300
# 300
# 300

# %%
x1 = gauss.modify_x(x,0.2)
gauss.error(x1)
gauss.l2error(x1)
# Out:
# 300
# 300
# 300

# %%
x1 = gauss.modify_x(x,0.5)
gauss.error(x1)
gauss.l2error(x1)
# Out:
# 300
# 300
# 300

# %% [markdown]
# #### Density as approximation

# %%
x1 = spline.modify_x(x,0.5)
spline.error_dens_appr(x1)
spline.l2error_dens_appr(x1)
# Out:
# 300
# 300
# 300

# %%
x1 = gauss.modify_x(x,0.2)
gauss.error_dens_appr(x1)
gauss.l2error_dens_appr(x1)

# %%
x1 = gauss.modify_x(x,0.5)
gauss.error_dens_appr(x1)
gauss.l2error_dens_appr(x1)
