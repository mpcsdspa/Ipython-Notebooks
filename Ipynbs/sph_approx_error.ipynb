# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
cd Desktop/PRABHU\ SIR
# Out:
# /home/mrinalgouda/Desktop/PRABHU SIR

# %%
import SPHA

# %% [markdown]
# The above plots show the function and derivative approximation of sin(2*pi*x) using both spline and gaussian kernel.

# %%
import gauss
# Out:
# 10

# %%
import spline
# Out:
# 10

# %%
import gauss_derivative
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]

# %%
cd Desktop/PRABHU\ SIR
# Out:
# /home/mrinalgouda/Desktop/PRABHU SIR

# %%
cd ../../Desktop/PRABHU\ SIR
# Out:
# /home/mrinalgouda/Desktop/PRABHU SIR

# %%
# %matplotlib inline

# %%
import spline_derivative

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.mgrid[-1:1:101*1j]
spline_derivative.error(x)
spline_derivative.l2error(x)
# Out:
# 10

# %% [markdown]
# Now using density of the particles from the kernel approximation

# %%
import spline

# %%
run spline.py

# %%
import gauss
# Out:
# 10
