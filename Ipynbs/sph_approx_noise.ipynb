# %% [markdown]
# # STUDY OF FUNCTION APPROXIMATION BY ADDING NOISE

# %%
cd Desktop/PRABHU\ SIR
# Out:
# /home/mrinalgouda/Desktop/PRABHU SIR

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.mgrid[-1:1:101j]

# %%
import spline;
# Out:
# 10

# %%
# %matplotlib inline

# %% [markdown]
# SPLINE FUNCTION APPROXIMATION WITH NOISE

# %%
a = spline.modify_x(x,0.2);
spline.error(a)
spline.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = spline.modify_x(x,0.6);
spline.error(a)
spline.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = spline.modify_x(x,1.0);
spline.error(a)
spline.l2error(a)
# Out:
# 10

# %% [markdown]
# GAUSS FUNCTION APPROXIMATION WITH NOISE

# %%
import gauss

# %%
x = np.mgrid[-1:1:101j]
a = gauss.modify_x(x,0.2);
gauss.error(a)
gauss.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = gauss.modify_x(x,0.6);
gauss.error(a)
gauss.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = gauss.modify_x(x,1.0);
gauss.error(a)
gauss.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = gauss.modify_x(x,1.2);
gauss.error(a)
gauss.l2error(a)
# Out:
# 10

# %% [markdown]
# SPLINE APPROXIMATION FOR FUNCTION DERIVATIVE WITH NOISE

# %%
import spline_derivative;
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = spline_derivative.modify_x(x,0.2);
spline_derivative.error(a)
spline_derivative.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = spline_derivative.modify_x(x,0.02);
spline_derivative.error(a)
spline_derivative.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = spline_derivative.modify_x(x,0.001);
spline_derivative.error(a)
spline_derivative.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]

# %% [markdown]
# GAUSS APPROXIMATION FOR FUNCTION DERIVATIVE WITH NOISE

# %%
import gauss_derivative

# %%
run gauss derivative.py
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = gauss_derivative.modify_x(x,0.2);
gauss_derivative.error(a)
gauss_derivative.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = gauss_derivative.modify_x(x,0.02);
gauss_derivative.error(a)
gauss_derivative.l2error(a)
# Out:
# 10

# %%
x = np.mgrid[-1:1:101j]
a = gauss_derivative.modify_x(x,0.002);
gauss_derivative.error(a)
gauss_derivative.l2error(a)
# Out:
# 10
